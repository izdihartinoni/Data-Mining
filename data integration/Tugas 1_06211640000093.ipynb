# %% [markdown]
# ## Tugas 1

# %%
### data integration
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("3.csv",sep=";")
data2=pd.read_csv("4.csv",sep=";")
data1
# Out:
#            time station AMB_TEMP  CH4    CO PH_RAIN PM10 PM2.5 RAINFALL  \
# 0    01/01/2015    0:00  Banqiao   16  2:01      37   NR   177      78x
# 1    01/01/2015    1:00  Banqiao   16  2:01      36   NR   178      77x
# 2    01/01/2015    2:00  Banqiao   16  2:01      38   NR   163      72x
# 3    01/01/2015    3:00  Banqiao   15     2      39   NR   147      65x
# 4    01/01/2015    4:00  Banqiao   15     2      38   NR   131      56x
# 5    01/01/2015    5:00  Banqiao   14     2      37   NR   112      46x
# 6    01/01/2015    6:00  Banqiao   14     2      29   NR   103      45x
# 7    01/01/2015    7:00  Banqiao   14     2      27   NR   104      42x
# 8    01/01/2015    8:00  Banqiao   14     2      29   NR   111      45x
# 9    01/01/2015    9:00  Banqiao   14     2      29   NR   111      46x
# 10   01/01/2015   10:00  Banqiao   15     2      35   NR   100      41x
# 11   01/01/2015   11:00  Banqiao   14     2      39   NR    92      38x
# ...

# %%
data_complate=pd.merge(data1,data2,on='station')
data_complate.head()
# Out:
#          time station AMB_TEMP  CH4    CO PH_RAIN_x PM10_x PM2.5_x RAINFALL_x  \
# 0  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 1  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 2  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 3  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 4  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
#
#   RAIN_COND_x     ...     RAIN_COND_y RH_y SO2_y THC_y UVB_y WD_HR_y  \
# 0          NR     ...              NR   NR    57    12  2:02       0
# 1          NR     ...              NR   NR    58  1:06  2:01       0
# 2          NR     ...              NR   NR    59  1:03  2:01       0
# 3          NR     ...              NR   NR    79  4:07  2:07       0
# 4          NR     ...              NR   NR    80  2:01  2:08       0
#
#   WIND_DIREC_y WIND_SPEED_y WS_HR_y Unnamed: 19
# ...

# %%
data_complate.head(10)
# Out:
#          time station AMB_TEMP  CH4    CO PH_RAIN_x PM10_x PM2.5_x RAINFALL_x  \
# 0  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 1  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 2  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 3  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 4  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 5  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 6  01/01/2015    0:00  Banqiao   16  2:01        37     NR     177        78x
# 7  02/01/2015    0:00  Banqiao   13     2        31     NR      42        12x
# 8  02/01/2015    0:00  Banqiao   13     2        31     NR      42        12x
# 9  02/01/2015    0:00  Banqiao   13     2        31     NR      42        12x
#
#   RAIN_COND_x     ...     RAIN_COND_y RH_y SO2_y THC_y UVB_y WD_HR_y  \
# ...

# %% [markdown]
# ## Sumber tugas : https://www.kaggle.com/nelsonchu/air-quality-in-northern-taiwan
